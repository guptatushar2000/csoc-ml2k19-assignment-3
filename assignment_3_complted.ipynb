# %% [markdown]
# So far we've learnt the most basic but crucial algorithms a data scientist and a machine learning engineer must know. We've learnt the techniques for classification and regression, and we've done some very rudementary data exploration. Hopefully, you've also done the assignments and the mini projects in the courses we recommended you to do. In this assignment, we give you a very easy dataset on which you can perform both classification and regression tasks. The purpose of this assignment is for you to try your hand out at all the techniques you've learnt so far and work on a real dataset to figure out whether what you learnt up until now works.

# %% [markdown]
# ## Link to the Dataset
#
# https://archive.ics.uci.edu/ml/datasets/wine+quality

# %% [markdown]
# For you to submit this assingment, you'll have to give us the accuracy you're getting on your classification, what algorithms/techniques you used for classification and why. Also, you'll give us the minimum loss you got in your regression, what algorithms/techniques you used and why. Just as last assignment, you'll clone the original folder, work completely on this Jupyter notebook and submit all your work. Also, you'll include in a text cell the above things. Happy playing on this dataset!

# %% [markdown]
# ## Some things that must be present in the notebook
# - Read the dataset and display various details of data (correlation,some statistics etc..)
# - Split the data into train test split
# - Show some vizualizations
# - Models for both classification and regression.
# - Show the results clearly and all of them must be on the test set

# %% [markdown]
# This [book](https://github.com/dvrg/educate-resource-for-machine-learning/blob/master/6.%20Machine%20Learning%20Mastery%20With%20Python%20Understand%20Your%20Data%2C%20Create%20Accurate%20Models%20and%20work%20Projects%20End-to-End.pdf) is a great resource for data science/predictive modelling in general and can be used as reference book for this task and future. The book highlights all the necessary steps one must take to understand data and build powerful models in a simple and understandable manner.

# %% [markdown]
# ### Accuracy on your classification task and the reason you used this algorithm/technique ->
#                 for red wine accuracy was 100%
#                 for white wine accuracy was 100%

# %% [markdown]
# ### Minimum loss on you regression task and the reason you used this algorithm/technique ->
#                 for red wine accuracy was 99.34%
#                 for white wine accuracy was 99.89%

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
names = ['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar', 'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
dt = pd.read_csv(r'winequality-red.csv', names = names, delimiter = ';')
dt = dt.drop([0], axis = 0)
dt.head(20)
# Out:
#    fixed_acidity volatile_acidity citric_acid residual_sugar chlorides  \
# 1            7.4              0.7           0            1.9     0.076
# 2            7.8             0.88           0            2.6     0.098
# 3            7.8             0.76        0.04            2.3     0.092
# 4           11.2             0.28        0.56            1.9     0.075
# 5            7.4              0.7           0            1.9     0.076
# 6            7.4             0.66           0            1.8     0.075
# 7            7.9              0.6        0.06            1.6     0.069
# 8            7.3             0.65           0            1.2     0.065
# 9            7.8             0.58        0.02              2     0.073
# 10           7.5              0.5        0.36            6.1     0.071
# 11           6.7             0.58        0.08            1.8     0.097
# 12           7.5              0.5        0.36            6.1     0.071
# 13           5.6            0.615           0            1.6     0.089
# 14           7.8             0.61        0.29            1.6     0.114
# 15           8.9             0.62        0.18            3.8     0.176
# 16           8.9             0.62        0.19            3.9      0.17
# 17           8.5             0.28        0.56            1.8     0.092
# 18           8.1             0.56        0.28            1.7     0.368
# 19           7.4             0.59        0.08            4.4     0.086
# 20           7.9             0.32        0.51            1.8     0.341
#
#    free_sulfur_dioxide total_sulfur_dioxide density    pH sulphates alcohol  \
# 1                   11                   34  0.9978  3.51      0.56     9.4
# 2                   25                   67  0.9968   3.2      0.68     9.8
# 3                   15                   54   0.997  3.26      0.65     9.8
# 4                   17                   60   0.998  3.16      0.58     9.8
# 5                   11                   34  0.9978  3.51      0.56     9.4
# 6                   13                   40  0.9978  3.51      0.56     9.4
# 7                   15                   59  0.9964   3.3      0.46     9.4
# 8                   15                   21  0.9946  3.39      0.47      10
# 9                    9                   18  0.9968  3.36      0.57     9.5
# 10                  17                  102  0.9978  3.35       0.8    10.5
# 11                  15                   65  0.9959  3.28      0.54     9.2
# 12                  17                  102  0.9978  3.35       0.8    10.5
# 13                  16                   59  0.9943  3.58      0.52     9.9
# 14                   9                   29  0.9974  3.26      1.56     9.1
# 15                  52                  145  0.9986  3.16      0.88     9.2
# 16                  51                  148  0.9986  3.17      0.93     9.2
# 17                  35                  103  0.9969   3.3      0.75    10.5
# 18                  16                   56  0.9968  3.11      1.28     9.3
# 19                   6                   29  0.9974  3.38       0.5       9
# 20                  17                   56  0.9969  3.04      1.08     9.2
#
#    quality
# 1        5
# 2        5
# 3        5
# 4        6
# 5        5
# 6        5
# 7        5
# 8        7
# 9        7
# 10       5
# 11       5
# 12       5
# 13       5
# 14       5
# 15       5
# 16       5
# 17       7
# 18       5
# 19       4
# 20       6

# %%
print(dt.shape)
# Out:
# (1599, 12)

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1599 entries, 1 to 1599
# Data columns (total 12 columns):
# fixed_acidity           1599 non-null object
# volatile_acidity        1599 non-null object
# citric_acid             1599 non-null object
# residual_sugar          1599 non-null object
# chlorides               1599 non-null object
# free_sulfur_dioxide     1599 non-null object
# total_sulfur_dioxide    1599 non-null object
# density                 1599 non-null object
# pH                      1599 non-null object
# sulphates               1599 non-null object
# alcohol                 1599 non-null object
# quality                 1599 non-null object
# dtypes: object(12)
# memory usage: 87.4+ KB

# %%
dt.fixed_acidity = pd.to_numeric(dt.fixed_acidity, errors = 'coerce').astype('float64')
dt.volatile_acidity = pd.to_numeric(dt.volatile_acidity, errors = 'coerce').astype('float64')
dt.citric_acid = pd.to_numeric(dt.citric_acid, errors = 'coerce').astype('float64')
dt.residual_sugar = pd.to_numeric(dt.residual_sugar, errors = 'coerce').astype('float64')
dt.chlorides = pd.to_numeric(dt.chlorides, errors = 'coerce').astype('float64')
dt.free_sulfur_dioxide = pd.to_numeric(dt.free_sulfur_dioxide, errors = 'coerce').astype('float64')
dt.total_sulfur_dioxide = pd.to_numeric(dt.total_sulfur_dioxide, errors = 'coerce').astype('float64')
dt.density = pd.to_numeric(dt.density, errors = 'coerce').astype('float64')
dt.pH = pd.to_numeric(dt.pH, errors = 'coerce').astype('float64')
dt.sulphates = pd.to_numeric(dt.sulphates, errors = 'coerce').astype('float64')
dt.alcohol = pd.to_numeric(dt.alcohol, errors = 'coerce').astype('float64')
dt.quality = pd.to_numeric(dt.quality, errors = 'coerce').astype('float64')

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1599 entries, 1 to 1599
# Data columns (total 12 columns):
# fixed_acidity           1599 non-null float64
# volatile_acidity        1599 non-null float64
# citric_acid             1599 non-null float64
# residual_sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free_sulfur_dioxide     1599 non-null float64
# total_sulfur_dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null float64
# dtypes: float64(12)
# memory usage: 162.4 KB

# %%
dt.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
dt.quality.value_counts().sort_index()
# Out:
# 3.0     10
# 4.0     53
# 5.0    681
# 6.0    638
# 7.0    199
# 8.0     18
# Name: quality, dtype: int64

# %%
corr = dt.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row0_col1 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row0_col2 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row0_col3 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row0_col4 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row0_col6 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row0_col7 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row0_col9 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row0_col10 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row0_col11 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row1_col0 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row1_col3 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row1_col4 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row1_col5 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row1_col6 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row1_col7 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row1_col8 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row1_col10 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row1_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row2_col0 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row2_col3 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row2_col4 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row2_col5 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row2_col6 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row2_col7 {
#             background-color:  #eed0c0;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row2_col8 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row2_col9 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row2_col10 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row2_col11 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row3_col0 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row3_col1 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row3_col2 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row3_col4 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row3_col5 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row3_col6 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row3_col7 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row3_col8 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row3_col9 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row3_col10 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row3_col11 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row4_col0 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row4_col1 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row4_col2 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row4_col3 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row4_col5 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row4_col6 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row4_col7 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row4_col8 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row4_col9 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row4_col10 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_fccafe86_95e3_11e9_b8e6_c01885c98c08row4_col11 {
#             background-color:  #779af7;
#             color:  #0

# %%
dt.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
dt.plot(kind='density', subplots=True, layout=(11,11), sharex=False)
plt.show()

# %%
skew = dt.skew()
print(skew)
# Out:
# fixed_acidity           0.982751
# volatile_acidity        0.671593
# citric_acid             0.318337
# residual_sugar          4.540655
# chlorides               5.680347
# free_sulfur_dioxide     1.250567
# total_sulfur_dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
def binary(quality):
    if quality >= 6:
        return 1
    else:
        return 0

# %%
dt['binary'] = dt['quality'].apply(binary)

# %%
X = dt.drop('quality', axis=1)
X = dt.drop('binary', axis=1)
Y = dt.binary
validation_size = 0.20
seed = 7
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y,
test_size=validation_size, random_state=seed)

# %%
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
# evaluate each model in turn
results = []
names = []
for name, model in models:
    kfold = KFold(n_splits=10, random_state=seed)
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LR: 0.997656 (0.003580)
# LDA: 0.999219 (0.002344)
# KNN: 0.746672 (0.025528)
# CART: 1.000000 (0.000000)
# NB: 0.967169 (0.011987)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVM: 0.874102 (0.026121)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
cart = DecisionTreeClassifier()
cart.fit(X_train, Y_train)
predictions = cart.predict(X_validation)
print(accuracy_score(Y_validation, predictions))
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# 1.0
# [[133   0]
#  [  0 187]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       133
#            1       1.00      1.00      1.00       187
#
#    micro avg       1.00      1.00      1.00       320
#    macro avg       1.00      1.00      1.00       320
# weighted avg       1.00      1.00      1.00       320

# %%
lr = LogisticRegression()
lr.fit(X_train, Y_train)
predictions = lr.predict(X_validation)
print(accuracy_score(Y_validation, predictions))
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# 0.99375
# [[133   0]
#  [  2 185]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       133
#            1       1.00      0.99      0.99       187
#
#    micro avg       0.99      0.99      0.99       320
#    macro avg       0.99      0.99      0.99       320
# weighted avg       0.99      0.99      0.99       320
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
names = ['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar', 'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
dt = pd.read_csv(r'winequality-white.csv', names = names, delimiter = ';')
dt = dt.drop([0], axis = 0)
dt.head(20)
# Out:
#    fixed_acidity volatile_acidity citric_acid residual_sugar chlorides  \
# 1              7             0.27        0.36           20.7     0.045
# 2            6.3              0.3        0.34            1.6     0.049
# 3            8.1             0.28         0.4            6.9      0.05
# 4            7.2             0.23        0.32            8.5     0.058
# 5            7.2             0.23        0.32            8.5     0.058
# 6            8.1             0.28         0.4            6.9      0.05
# 7            6.2             0.32        0.16              7     0.045
# 8              7             0.27        0.36           20.7     0.045
# 9            6.3              0.3        0.34            1.6     0.049
# 10           8.1             0.22        0.43            1.5     0.044
# 11           8.1             0.27        0.41           1.45     0.033
# 12           8.6             0.23         0.4            4.2     0.035
# 13           7.9             0.18        0.37            1.2      0.04
# 14           6.6             0.16         0.4            1.5     0.044
# 15           8.3             0.42        0.62          19.25      0.04
# 16           6.6             0.17        0.38            1.5     0.032
# 17           6.3             0.48        0.04            1.1     0.046
# 18           6.2             0.66        0.48            1.2     0.029
# 19           7.4             0.34        0.42            1.1     0.033
# 20           6.5             0.31        0.14            7.5     0.044
#
#    free_sulfur_dioxide total_sulfur_dioxide density    pH sulphates alcohol  \
# 1                   45                  170   1.001     3      0.45     8.8
# 2                   14                  132   0.994   3.3      0.49     9.5
# 3                   30                   97  0.9951  3.26      0.44    10.1
# 4                   47                  186  0.9956  3.19       0.4     9.9
# 5                   47                  186  0.9956  3.19       0.4     9.9
# 6                   30                   97  0.9951  3.26      0.44    10.1
# 7                   30                  136  0.9949  3.18      0.47     9.6
# 8                   45                  170   1.001     3      0.45     8.8
# 9                   14                  132   0.994   3.3      0.49     9.5
# 10                  28                  129  0.9938  3.22      0.45      11
# 11                  11                   63  0.9908  2.99      0.56      12
# 12                  17                  109  0.9947  3.14      0.53     9.7
# 13                  16                   75   0.992  3.18      0.63    10.8
# 14                  48                  143  0.9912  3.54      0.52    12.4
# 15                  41                  172  1.0002  2.98      0.67     9.7
# 16                  28                  112  0.9914  3.25      0.55    11.4
# 17                  30                   99  0.9928  3.24      0.36     9.6
# 18                  29                   75  0.9892  3.33      0.39    12.8
# 19                  17                  171  0.9917  3.12      0.53    11.3
# 20                  34                  133  0.9955  3.22       0.5     9.5
#
#    quality
# 1        6
# 2        6
# 3        6
# 4        6
# 5        6
# 6        6
# 7        6
# 8        6
# 9        6
# 10       6
# 11       5
# 12       5
# 13       5
# 14       7
# 15       5
# 16       7
# 17       6
# 18       8
# 19       6
# 20       5

# %%
print(dt.shape)
# Out:
# (4898, 12)

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4898 entries, 1 to 4898
# Data columns (total 12 columns):
# fixed_acidity           4898 non-null object
# volatile_acidity        4898 non-null object
# citric_acid             4898 non-null object
# residual_sugar          4898 non-null object
# chlorides               4898 non-null object
# free_sulfur_dioxide     4898 non-null object
# total_sulfur_dioxide    4898 non-null object
# density                 4898 non-null object
# pH                      4898 non-null object
# sulphates               4898 non-null object
# alcohol                 4898 non-null object
# quality                 4898 non-null object
# dtypes: object(12)
# memory usage: 267.9+ KB

# %%
dt.fixed_acidity = pd.to_numeric(dt.fixed_acidity, errors = 'coerce').astype('float64')
dt.volatile_acidity = pd.to_numeric(dt.volatile_acidity, errors = 'coerce').astype('float64')
dt.citric_acid = pd.to_numeric(dt.citric_acid, errors = 'coerce').astype('float64')
dt.residual_sugar = pd.to_numeric(dt.residual_sugar, errors = 'coerce').astype('float64')
dt.chlorides = pd.to_numeric(dt.chlorides, errors = 'coerce').astype('float64')
dt.free_sulfur_dioxide = pd.to_numeric(dt.free_sulfur_dioxide, errors = 'coerce').astype('float64')
dt.total_sulfur_dioxide = pd.to_numeric(dt.total_sulfur_dioxide, errors = 'coerce').astype('float64')
dt.density = pd.to_numeric(dt.density, errors = 'coerce').astype('float64')
dt.pH = pd.to_numeric(dt.pH, errors = 'coerce').astype('float64')
dt.sulphates = pd.to_numeric(dt.sulphates, errors = 'coerce').astype('float64')
dt.alcohol = pd.to_numeric(dt.alcohol, errors = 'coerce').astype('float64')
dt.quality = pd.to_numeric(dt.quality, errors = 'coerce').astype('float64')

# %%
dt.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
dt.quality.value_counts().sort_index()
# Out:
# 3.0      20
# 4.0     163
# 5.0    1457
# 6.0    2198
# 7.0     880
# 8.0     175
# 9.0       5
# Name: quality, dtype: int64

# %%
corr = dt.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row0_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row0_col2 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row0_col3 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row0_col4 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row0_col5 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row0_col6 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row0_col7 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row0_col9 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row0_col10 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row0_col11 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row1_col0 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row1_col2 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row1_col3 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row1_col4 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row1_col5 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row1_col6 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row1_col7 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row1_col8 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row1_col10 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row1_col11 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row2_col0 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row2_col1 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row2_col3 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row2_col4 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row2_col5 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row2_col6 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row2_col7 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row2_col8 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row2_col9 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row2_col10 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row2_col11 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row3_col0 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row3_col1 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row3_col2 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row3_col4 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row3_col5 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row3_col6 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row3_col7 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row3_col8 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row3_col9 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row3_col10 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row3_col11 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row4_col0 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row4_col1 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row4_col2 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row4_col3 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row4_col5 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row4_col6 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row4_col7 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row4_col8 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row4_col9 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row4_col10 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_09805aa8_95e4_11e9_9fa3_c01885c98c08row4_col11 {
#             background-color:  #516ddb;
#             color:  #0

# %%
dt.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
dt.plot(kind='density', subplots=True, layout=(11,11), sharex=False)
plt.show()

# %%
skew = dt.skew()
print(skew)
# Out:
# fixed_acidity           0.647751
# volatile_acidity        1.576980
# citric_acid             1.281920
# residual_sugar          1.077094
# chlorides               5.023331
# free_sulfur_dioxide     1.406745
# total_sulfur_dioxide    0.390710
# density                 0.977773
# pH                      0.457783
# sulphates               0.977194
# alcohol                 0.487342
# quality                 0.155796
# dtype: float64

# %%
def binary(quality):
    if quality >= 6:
        return 1
    else:
        return 0

# %%
dt['binary'] = dt['quality'].apply(binary)

# %%
X = dt.drop('quality', axis=1)
X = dt.drop('binary', axis=1)
Y = dt.binary
validation_size = 0.20
seed = 7
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y,
test_size=validation_size, random_state=seed)

# %%
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
# evaluate each model in turn
results = []
names = []
for name, model in models:
    kfold = KFold(n_splits=10, random_state=seed)
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LR: 0.999490 (0.001020)
# LDA: 1.000000 (0.000000)
# KNN: 0.732502 (0.022993)
# CART: 1.000000 (0.000000)
# NB: 0.969373 (0.007819)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVM: 0.803205 (0.016500)

# %%
cart = DecisionTreeClassifier()
cart.fit(X_train, Y_train)
predictions = cart.predict(X_validation)
print(accuracy_score(Y_validation, predictions))
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# 1.0
# [[325   0]
#  [  0 655]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       325
#            1       1.00      1.00      1.00       655
#
#    micro avg       1.00      1.00      1.00       980
#    macro avg       1.00      1.00      1.00       980
# weighted avg       1.00      1.00      1.00       980

# %%
lr = LogisticRegression()
lr.fit(X_train, Y_train)
predictions = lr.predict(X_validation)
print(accuracy_score(Y_validation, predictions))
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# 0.9989795918367347
# [[325   0]
#  [  1 654]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       325
#            1       1.00      1.00      1.00       655
#
#    micro avg       1.00      1.00      1.00       980
#    macro avg       1.00      1.00      1.00       980
# weighted avg       1.00      1.00      1.00       980
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
